# %% [markdown]
# # Atividade 1 — Exercícios com os comandos básicos de pandas para EDA
#
#
# Responda as perguntas abaixo no notebook (cada resposta deve ter ao menos uma célula de código que produza o output e, logo abaixo, uma célula de texto com a sua interpretação).

# %% [markdown]
# ## 1) Carregue o dataset e mostre as primeiras 10 linhas.

# %%
import pandas as pd
df = pd.read_csv('/content/emendas.csv')
display(df.head(10))
# Out:
#   Código da Emenda  Ano da Emenda  \
# 0   Sem informação           2014
# 1   Sem informação           2014
# 2   Sem informação           2014
# 3   Sem informação           2014
# 4   Sem informação           2014
# 5   Sem informação           2014
# 6   Sem informação           2014
# 7   Sem informação           2014
# 8   Sem informação           2014
# 9   Sem informação           2014
#
#                                       Tipo de Emenda  \
# 0  Emenda Individual - Transferências com Finalid...
# 1  Emenda Individual - Transferências com Finalid...
# 2  Emenda Individual - Transferências com Finalid...
# 3  Emenda Individual - Transferências com Finalid...
# 4  Emenda Individual - Transferências com Finalid...
# 5  Emenda Individual - Transferências com Finalid...
# 6  Emenda Individual - Transferências com Finalid...
# 7  Emenda Individual - Transferências com Finalid...
# 8  Emenda Individual - Transferências com Finalid...
# ...

# %% [markdown]
# Explique em uma frase o que você observa nas primeiras 10 linhas.
#
# As primeiras 10 linhas (0-9) mostram registros de emendas parlamentares individuais do ano de 2014, todas do tipo "Transferências com Finalidade", destinadas a municípios de diferentes estados brasileiros, mas com vários campos de identificação preenchidos como "Sem Informação", o que indica bastante inconsistência nos dados

# %% [markdown]
# ## 2) Quantas linhas e colunas o dataset possui?

# %%
df.shape
# Out:
# (20632, 28)

# %% [markdown]
# Explique o que esses números significam.
#
# significa que tem 20632 linhas e 28 colunas

# %% [markdown]
# ## 3) Liste os nomes das colunas e descreva brevemente o que você entende que cada coluna representa.

# %%
df.columns.tolist()
# Out:
# ['Código da Emenda',
#  'Ano da Emenda',
#  'Tipo de Emenda',
#  'Código do Autor da Emenda',
#  'Nome do Autor da Emenda',
#  'Número da emenda',
#  'Localidade de aplicação do recurso',
#  'Código Município IBGE',
#  'Município',
#  'Código UF IBGE',
#  'UF',
#  'Região',
#  'Código Função',
#  'Nome Função',
#  'Código Subfunção',
#  'Nome Subfunção',
#  'Código Programa',
#  'Nome Programa',
#  'Código Ação',
#  'Nome Ação',
#  'Código Plano Orçamentário',
#  'Nome Plano Orçamentário',
#  'Valor Empenhado',
#  'Valor Liquidado',
#  'Valor Pago',
#  'Valor Restos A Pagar Inscritos',
#  'Valor Restos A Pagar Cancelados',
#  'Valor Restos A Pagar Pagos']

# %% [markdown]
# Escreva sua breve descrição das colunas, como se estivesse criando um dicionário de variáveis para que leitor entenda.
#
#
#
#
#
# ### Dicionário de Variáveis
#
# | Coluna | Descrição |
# |---|---|
# | `Código da Emenda` | Identificador único da emenda parlamentar |
# | `Ano da Emenda` | Ano em que a emenda foi registrada |
# | `Tipo de Emenda` | Classificação da emenda (ex: individual, bancada) |
# | `Código do Autor da Emenda` | Identificador do parlamentar autor da emenda |
# | `Nome do Autor da Emenda` | Nome do parlamentar que propôs a emenda |
# | `Número da Emenda` | Número sequencial da emenda |
# | `Localidade de aplicação do recurso` | Local onde o recurso será aplicado |
# | `Código Município IBGE` | Código oficial IBGE do município beneficiado |
# | `Município` | Nome do município beneficiado |
# | `Código UF IBGE` | Código numérico IBGE do estado |
# | `UF` | Sigla do estado beneficiado |
# | `Região` | Região do Brasil onde o recurso é aplicado |
# | `Código Função` | Código da função orçamentária (ex: saúde, educação) |
# | `Nome Função` | Nome da função orçamentária |
# | `Código Subfunção` | Código da subfunção orçamentária |
# | `Nome Subfunção` | Detalhamento da subfunção orçamentária |
# | `Código Programa` | Código do programa governamental vinculado |
# | `Nome Programa` | Nome do programa governamental vinculado |
# | `Código Ação` | Código da ação orçamentária específica |
# | `Nome Ação` | Descrição da ação orçamentária |
# | `Código Plano Orçamentário` | Código do plano orçamentário |
# | `Nome Plano Orçamentário` | Descrição do plano orçamentário |
# | `Valor Empenhado` | Valor comprometido/reservado para a emenda |
# | `Valor Liquidado` | Valor confirmado após prestação de contas |
# | `Valor Pago` | Valor efetivamente pago ao beneficiário |
# | `Valor Restos A Pagar Inscritos` | Valor inscrito em restos a pagar (não pago no ano) |
# | `Valor Restos A Pagar Cancelados` | Valor de restos a pagar que foi cancelado |
# | `Valor Restos A Pagar Pagos` | Valor de restos a pagar que foi efetivamente

# %% [markdown]
# ## 4) Existem valores nulos? quantos?

# %%
df.isnull().sum()
# Out:
# Código da Emenda                      0
# Ano da Emenda                         0
# Tipo de Emenda                        0
# Código do Autor da Emenda             0
# Nome do Autor da Emenda               0
# Número da emenda                      0
# Localidade de aplicação do recurso    0
# Código Município IBGE                 0
# Município                             0
# Código UF IBGE                        0
# UF                                    0
# Região                                0
# Código Função                         0
# Nome Função                           0
# Código Subfunção                      0
# Nome Subfunção                        0
# Código Programa                       1
# Nome Programa                         1
# Código Ação                           1
# Nome Ação                             1
# Código Plano Orçamentário             1
# Nome Plano Orçamentário               1
# Valor Empenhado                       1
# ...

# %% [markdown]
# sim exite nulos e sao no total 12
#
#
# | Coluna | Nulos |
# |---|---|
# | `Código Programa` | 1 |
# | `Nome Programa` | 1 |
# | `Código Ação` | 1 |
# | `Nome Ação` | 1 |
# | `Código Plano Orçamentário` | 1 |
# | `Nome Plano Orçamentário` | 1 |
# | `Valor Empenhado` | 1 |
# | `Valor Liquidado` | 1 |
# | `Valor Pago` | 1 |
# | `Valor Restos A Pagar Inscritos` | 1 |
# | `Valor Restos A Pagar Cancelados` | 1 |
# | `Valor Restos A Pagar Pagos` | 1 |

# %% [markdown]
# ## 5) Mostre os tipos das variáveis (se int, string, boolean, float...) e analise se alguma variável parece ter o tipo errado. Faça isso da maneira mais objetiva e otimizada possível.

# %%
df.dtypes
# Out:
# Código da Emenda                      object
# Ano da Emenda                          int64
# Tipo de Emenda                        object
# Código do Autor da Emenda             object
# Nome do Autor da Emenda               object
# Número da emenda                      object
# Localidade de aplicação do recurso    object
# Código Município IBGE                 object
# Município                             object
# Código UF IBGE                         int64
# UF                                    object
# Região                                object
# Código Função                         object
# Nome Função                           object
# Código Subfunção                      object
# Nome Subfunção                        object
# Código Programa                       object
# Nome Programa                         object
# Código Ação                           object
# Nome Ação                             object
# Código Plano Orçamentário             object
# ...

# %% [markdown]
# Se alguma coluna estiver com o tipo errado, escreva abaixo qual é e por que isso pode atrapalhar análises.
#
# **Dica:** Se alguma variável tiver no tipo o nome "object", isso se refere a texto.
#
#
# As colunas de valores financeiros estão como texto (object) em vez de float64, o que impede qualquer cálculo matemático sobre elas. Alem de que o python interpreta como string

# %% [markdown]
# ## 6) Usando a coluna `Ano da Emenda` como base, descubra até que ano o dataset está atualizado (mostre as 8 primeiras linhas do df ordenado desc).

# %%
df_sorted = df.sort_values('Ano da Emenda', ascending=False)
display(df_sorted.head(8))
print(df['Ano da Emenda'].max())
# Out:
#       Código da Emenda  Ano da Emenda      Tipo de Emenda  \
# 20623   Sem informação           2016  Emenda de Comissão
# 20622   Sem informação           2016  Emenda de Comissão
# 20621   Sem informação           2016  Emenda de Comissão
# 20620   Sem informação           2016  Emenda de Comissão
# 20619   Sem informação           2016  Emenda de Comissão
# 20618   Sem informação           2016  Emenda de Comissão
# 20617   Sem informação           2016  Emenda de Comissão
# 20599   Sem informação           2016  Emenda de Comissão
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# 20623                       -99           RELATOR GERAL              S/I
# 20622                       -99           RELATOR GERAL              S/I
# 20621                       -99           RELATOR GERAL              S/I
# 20620                       -99           RELATOR GERAL              S/I
# 20619                       -99           RELATOR GERAL              S/I
# ...

# %% [markdown]
# Explique: qual é o ano mais recente presente no dataset?
#
# 2016

# %% [markdown]
# ## 7) execute um  `describe()` e explique uma conclusão simples que você consegue tirar a partir das estatísticas (se algumas colunas deveriam aparecer no describe mas não aparecem, indique o motivo que você acredita que esteja causando esse problema).

# %%
display(df.describe())
print(df.dtypes)
# Out:
#        Ano da Emenda  Código UF IBGE
# count   20632.000000    2.063200e+04
# mean     2014.738755    3.165636e+06
# std         0.867050    1.084096e+06
# min      2014.000000   -1.400000e+01
# 25%      2014.000000    2.500000e+06
# 50%      2014.000000    3.100000e+06
# 75%      2016.000000    4.100000e+06
# max      2016.000000    5.300000e+06
# Código da Emenda                      object
# Ano da Emenda                          int64
# Tipo de Emenda                        object
# Código do Autor da Emenda             object
# Nome do Autor da Emenda               object
# Número da emenda                      object
# Localidade de aplicação do recurso    object
# Código Município IBGE                 object
# Município                             object
# Código UF IBGE                         int64
# UF                                    object
# Região                                object
# Código Função                         object
# ...

# %% [markdown]
# ## 8) Mostre as últimas 5 linhas do dataset e escreva se a última linha parece completa (sem muitos nulos) ou não.

# %%
df.tail(5)
# Out:
#       Código da Emenda  Ano da Emenda      Tipo de Emenda  \
# 20627   Sem informação           2016  Emenda de Comissão
# 20628   Sem informação           2016  Emenda de Comissão
# 20629   Sem informação           2016  Emenda de Comissão
# 20630   Sem informação           2016  Emenda de Comissão
# 20631   Sem informação           2016  Emenda de Comissão
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# 20627                       -99           RELATOR GERAL              S/I
# 20628                       -99           RELATOR GERAL              S/I
# 20629                       -99           RELATOR GERAL              S/I
# 20630                       -99           RELATOR GERAL              S/I
# 20631                       -99           RELATOR GERAL              S/I
#
#       Localidade de aplicação do recurso Código Município IBGE  \
# 20627           CERRO GRANDE DO SUL - RS               4305173
# ...

# %% [markdown]
# Interprete a completude da última linha.
#
# A partir da coluna "Código UF IBGE" a linha foi preenchida como NaN  ou seja  é um campo vazio

# %% [markdown]
# ## 9) existem valores duplicados no dataframe? Caso positivo, quantos?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
